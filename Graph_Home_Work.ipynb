# %%
from enum import Enum
from datetime import datetime

import numpy as np
import pandas as pd
import networkx as nx
from tqdm import tqdm
from tensorflow import keras
from stellargraph import StellarGraph
from stellargraph.layer import Node2Vec, link_classification, GraphSAGE, link_regression
from stellargraph.data import BiasedRandomWalk, UnsupervisedSampler
from stellargraph.mapper import Node2VecLinkGenerator, Node2VecNodeGenerator

from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import plotly.express as px

from sklearn.ensemble import GradientBoostingRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor

import optuna
from sklearn.model_selection import KFold

# %% [markdown]
# # Задание - Предсказание уровня экспресси белка

# %% [markdown]
# <img src='https://www.researchgate.net/publication/313504607/figure/fig3/AS:459880453677066@1486655453033/Protein-protein-interaction-PPI-network-of-DEGs-by-STRING-The-interaction-score-was.png'>

# %% [markdown]
# <div class="alert alert-info">
# <b>Про биологию</b>
#
# Экспрессия — процесс, в ходе которого наследственная информация от гена (последовательности нуклеотидов ДНК) преобразуется в функциональный продукт — белок. Уровнем экспрессии называют - количество белка, производящегося в этом процессе. Чем выше экспрессия белка, тем большее количество этого белка появляется в клетках человека.

# %% [markdown]
# <div class="alert alert-info">
# <b>Важность задачи</b>
#
# Существует множество причин необходимости в знании уровня экспресии белка. Например - это позволяет ученым разрабатывать лекарственные средства и оптимизировать их разработку. Теперь вам предстоит побыть в роли биоинформатика и помочь науке!
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Про Датасет</b>
#
# Датасет представляет собой граф взаимойдествия белков. Где узлы это белки, взаимодействие между белками это ребро.
#
# Для каждого белка известен уровень его экспрессии. Ниже приведен список ребер `edges`. Информация по экспрессии белков, разбитая на `train` и `test`.
#
#
# </div>

# %%
#Список ребер графа 
edges = pd.read_csv("./edges.csv", sep=",", header=None) # Подгрузим данные
edges.head()
# Out:
#      0    1
# 0  344   50
# 1  344  153
# 2  344  532
# 3  344  679
# 4  344  986

# %%
#Подгрузим тренирочную выборку
train = pd.read_csv("./train.csv", sep=",") # Подгрузим данные
train.head()
# Out:
#      target   node
# 0  0.251968  11142
# 1  0.689541   2243
# 2  0.678245  15514
# 3  0.272500  20944
# 4  0.248888   8721

# %%
# Подгрузим отложенную выборку для валидации
test = pd.read_csv("./test.csv", sep=",")
test.head()
# Out:
#      target   node
# 0  0.279231    817
# 1  0.380795   9574
# 2  0.686527   1607
# 3  0.303594   4782
# 4  0.367374  24125

# %% [markdown]
# <div class="alert alert-info">
# <b>Про Задачу</b>
#
# Вам предлагается предсказать экспрессию белков (`target`) по приведенным данным для отложенной выборки. Ответы в отложенной выборке `test` даны вам для самостоятельной валидации.

# %% [markdown]
# <div class="alert alert-info">
# <b>Замечание и комментарии</b>
#
#
#
# По ряду причин датасет был упрощен так, чтобы выполнялись следующие условия:
# * у графа одна компонента связанности.
# * удалены слишком крупные хабы
# * плотность связей графа уменьшена
# * решить задачу можно классическими ML подходами

# %% [markdown]
# <div class="alert alert-info">
# <b>Оценка результатов</b>
#
#
#
# Оценка точности модели будет оцениваться по метрике MSE на отложенной выборке `test`
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Автор задачи</b>
#
# По всем дополнительным вопросами писать Александру Миленькину
# * Телеграмм: Alerin75infskin
# * Почта: milenkin.aa@phystech.edu
#
# </div>

# %% [markdown]
# ## EDA

# %%
px.histogram(train['target'], nbins=100, histnorm='percent')

# %%
high_expression_counts = edges[edges[0].isin(train[train['target'] > 2.0]['node'])].groupby(0).agg(count=(1, 'count'))
high_expression_counts[['count']].quantile([0.05, 0.25, 0.5, 0.75, 0.95])
# Out:
#        count
# 0.05   27.45
# 0.25  130.75
# 0.50  297.50
# 0.75  450.00
# 0.95  973.10

# %%
low_expression_counts = edges[edges[0].isin(train[train['target'] <= 2.0]['node'])].groupby(0).agg(count=(1, 'count'))
low_expression_counts[['count']].quantile([0.05, 0.25, 0.5, 0.75, 0.95])
# Out:
#       count
# 0.05    4.0
# 0.25   19.0
# 0.50   37.0
# 0.75   62.0
# 0.95  148.0

# %%
px.histogram(test['target'], nbins=100, histnorm='percent')

# %%
test_high_expression_counts = edges[edges[0].isin(test[test['target'] > 2.0]['node'])].groupby(0).agg(count=(1, 'count'))
test_high_expression_counts[['count']].quantile([0.05, 0.25, 0.5, 0.75, 0.95])
# Out:
#         count
# 0.05    44.40
# 0.25   226.00
# 0.50   402.00
# 0.75   624.00
# 0.95  1294.75

# %%
test_low_expression_counts = edges[edges[0].isin(test[test['target'] <= 2.0]['node'])].groupby(0).agg(count=(1, 'count'))
test_low_expression_counts[['count']].quantile([0.05, 0.25, 0.5, 0.75, 0.95])
# Out:
#       count
# 0.05    4.0
# 0.25   18.0
# 0.50   36.0
# 0.75   62.0
# 0.95  162.3

# %% [markdown]
# Из данных выше можно сделать предположение, что количество связей коррелирует с уровнем экспрессии:

# %%
counts = edges.groupby(0).agg(count=(1, 'count')).reset_index()
node_count_target = pd.merge(train, counts, left_on='node', right_on=0, how='left')[['node', 'count', 'target']]
node_count_target['count'] = node_count_target['count'].fillna(0)

node_count_target[['target', 'count']].corr()
# Out:
#           target     count
# target  1.000000  0.791109
# count   0.791109  1.000000

# %%
print(f'Mean target in train set: {train["target"].mean():.3f}')
print(f'Median target in train set: {train["target"].median():.3f}')
# Out:
# Mean target in train set: 0.531
# Median target in train set: 0.340

# %%
print(f'Mean target in test set: {test["target"].mean():.3f}')
print(f'Median target in test set: {test["target"].median():.3f}')
# Out:
# Mean target in test set: 0.569
# Median target in test set: 0.342

# %% [markdown]
# ## Homework

# %% [markdown]
# ### Baseline

# %%
# baseline
mean_expression = train['target'].mean()
print(f'Mean expression (target): {mean_expression:.3f}')
# Out:
# Mean expression (target): 0.531

# %%
print(f'Baseline MSE: {mean_squared_error(test["target"], [mean_expression] * test.shape[0]):.3f}')
# Out:
# Baseline MSE: 0.754

# %% [markdown]
# Хорошая модель должна давать MSE ниже 0.754

# %% [markdown]
# ### ML model

# %%
class NotebookMode(Enum):
    FromScratch = 0
    Predefined = 1

mode = NotebookMode.Predefined

# %%
edges = nx.read_edgelist('./edges.csv', delimiter=',')
print(nx.info(edges))
# Out:
# Name:
# Type: Graph
# Number of nodes: 10000
# Number of edges: 594174
# Average degree: 118.8348

# %%
G = StellarGraph.from_networkx(edges)

# %%
def train_model(batch_size, epochs, emb_size, walk_number, walk_length):
    rw = BiasedRandomWalk(G, n=walk_number, length=walk_length, p=0.5, q=2.0, seed=1)
    unsupervised_samples = UnsupervisedSampler(G, nodes=list(G.nodes()), walker=rw)
    generator = Node2VecLinkGenerator(G, batch_size)
    node2vec = Node2Vec(emb_size, generator=generator)
    x_inp, x_out = node2vec.in_out_tensors()

    prediction = link_regression(output_dim=1, edge_embedding_method="dot")(x_out)

    model = keras.Model(inputs=x_inp, outputs=prediction)

    model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss=keras.losses.MSE)

    history = model.fit(
        generator.flow(unsupervised_samples), epochs=epochs, shuffle=True
    )

    timestamp = datetime.strftime(datetime.now(), '%Y-%m-%dT%H-%M-%S')
    model.save_weights(f'./model-{timestamp}-batch_size-{batch_size}-emb_size-{emb_size}.weights')

    x_inp_src = x_inp[0]
    x_out_src = x_out[0]
    embedding_model = keras.Model(inputs=x_inp_src, outputs=x_out_src)

    node_gen = Node2VecNodeGenerator(G, batch_size).flow([str(a) for a in G.nodes()])
    node_embeddings = embedding_model.predict(node_gen, verbose=0)

    df = pd.DataFrame(node_embeddings)
    df['node'] = pd.Series(G.nodes(), dtype=np.int64)

    df_train = df[df['node'].isin(train['node'])]
    df_train = pd.merge(df, train, on='node')

    df_test = df[df['node'].isin(test['node'])]
    df_test = pd.merge(df, test, on='node')

    dt = DecisionTreeRegressor(random_state=1)
    dt.fit(df_train[list(df_train)[:-2]], df_train['target'])

    mse = mean_squared_error(dt.predict(df_test[list(df_test)[:-2]]), df_test['target'])

    return dt, mse

# %% [markdown]
# Грубо оценим параметры embedding-ов

# %%
batch_size = 64
epochs = 2
emb_size = 64
walk_number = 10
walk_length = 5

mses = []

if mode == NotebookMode.FromScratch:
    for i in tqdm(range(1, 5)):
        for j in tqdm(range(1, 5)):
            model, mse = train_model(64 * i, epochs, 64 * j, walk_number, walk_length)
            mses.append({'batch_size': 64 * i, 'emb_size': 64 * j, 'mse': mse})
else:
    mses=[
        {'batch_size': 64, 'emb_size': 64, 'mse': 1.3511612146704406},
        {'batch_size': 64, 'emb_size': 128, 'mse': 1.2261683918563566},
        {'batch_size': 64, 'emb_size': 192, 'mse': 1.5015654672647705},
        {'batch_size': 64, 'emb_size': 256, 'mse': 1.3650220678643608},
        {'batch_size': 128, 'emb_size': 64, 'mse': 1.20258656355635},
        {'batch_size': 128, 'emb_size': 128, 'mse': 1.2764228195233913},
        {'batch_size': 128, 'emb_size': 192, 'mse': 1.35218135321154},
        {'batch_size': 128, 'emb_size': 256, 'mse': 1.1116913482023314},
        {'batch_size': 192, 'emb_size': 64, 'mse': 1.3060879966580796},
        {'batch_size': 192, 'emb_size': 128, 'mse': 1.2750152115094364},
        {'batch_size': 192, 'emb_size': 192, 'mse': 1.3842525803808972},
        {'batch_size': 192, 'emb_size': 256, 'mse': 1.3887266921972257},
        {'batch_size': 256, 'emb_size': 64, 'mse': 1.3721984636750395},
        {'batch_size': 256, 'emb_size': 128, 'mse': 1.4770992893051553},
        {'batch_size': 256, 'emb_size': 192, 'mse': 1.3716800160102811},
        {'batch_size': 256, 'emb_size': 256, 'mse': 1.6835760014453267}
    ]

# %%
sorted(mses, key=lambda x: x['mse'])
# Out:
# [{'batch_size': 128, 'emb_size': 256, 'mse': 1.1116913482023314},
#  {'batch_size': 128, 'emb_size': 64, 'mse': 1.20258656355635},
#  {'batch_size': 64, 'emb_size': 128, 'mse': 1.2261683918563566},
#  {'batch_size': 192, 'emb_size': 128, 'mse': 1.2750152115094364},
#  {'batch_size': 128, 'emb_size': 128, 'mse': 1.2764228195233913},
#  {'batch_size': 192, 'emb_size': 64, 'mse': 1.3060879966580796},
#  {'batch_size': 64, 'emb_size': 64, 'mse': 1.3511612146704406},
#  {'batch_size': 128, 'emb_size': 192, 'mse': 1.35218135321154},
#  {'batch_size': 64, 'emb_size': 256, 'mse': 1.3650220678643608},
#  {'batch_size': 256, 'emb_size': 192, 'mse': 1.3716800160102811},
#  {'batch_size': 256, 'emb_size': 64, 'mse': 1.3721984636750395},
#  {'batch_size': 192, 'emb_size': 192, 'mse': 1.3842525803808972},
#  {'batch_size': 192, 'emb_size': 256, 'mse': 1.3887266921972257},
#  {'batch_size': 256, 'emb_size': 128, 'mse': 1.4770992893051553},
#  {'batch_size': 64, 'emb_size': 192, 'mse': 1.5015654672647705},
#  {'batch_size': 256, 'emb_size': 256, 'mse': 1.6835760014453267}]

# %% [markdown]
# Наиоблее удачными получились `batch_size` равный 128 и `emb_size` равный 256. Обучим embedding-и с этими параметрами на большем числе эпох

# %%
batch_size = 128
epochs = 3
emb_size = 256
walk_number = 10
walk_length = 5

rw = BiasedRandomWalk(G, n=walk_number, length=walk_length, p=0.5, q=2.0, seed=1)
unsupervised_samples = UnsupervisedSampler(G, nodes=list(G.nodes()), walker=rw)
generator = Node2VecLinkGenerator(G, batch_size)
node2vec = Node2Vec(emb_size, generator=generator)
x_inp, x_out = node2vec.in_out_tensors()

prediction = link_regression(output_dim=1, edge_embedding_method="dot")(x_out)

model = keras.Model(inputs=x_inp, outputs=prediction)

model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss=keras.losses.MSE)

if mode == NotebookMode.FromScratch:
    history = model.fit(
        generator.flow(unsupervised_samples), epochs=epochs, shuffle=True
    )

    timestamp = datetime.strftime(datetime.now(), '%Y-%m-%dT%H-%M-%S')
    model.save_weights(f'./model.weights')
else:
    model.load_weights(f'./model.weights')

x_inp_src = x_inp[0]
x_out_src = x_out[0]
embedding_model = keras.Model(inputs=x_inp_src, outputs=x_out_src)

node_gen = Node2VecNodeGenerator(G, batch_size).flow([str(a) for a in G.nodes()])
node_embeddings = embedding_model.predict(node_gen, verbose=0)
# Out:
# link_regression: using 'dot' method to combine node embeddings into edge embeddings

# %% [markdown]
# #### Модель `DecisionTreeRegressor` только с embedding-ами и параметрами по умолчанию

# %%
def create_folds(df: pd.DataFrame) -> pd.DataFrame:
    n_splits: int = 5
    df["kfold"] = -1
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    for fold, (train_indicies, valid_indicies) in enumerate(kf.split(X=df)):
        df.loc[valid_indicies, "kfold"] = fold
    return df

# %%
df = pd.DataFrame(node_embeddings)
df['node'] = pd.Series(G.nodes(), dtype=np.int64)
df = pd.merge(df, counts, left_on='node', right_on=0, how='left')
df = df.rename(columns={'0_x': 0})
df = df.drop(['0_x', '0_y'], axis='columns', errors='ignore')
df['count'] = df['count'].fillna(0)
df = create_folds(df)

target_column = 'target'
emb_columns = [x for x in range(256)]
kfold_column = 'kfold'
count_column = ['count']

# %%
df_train = df[df['node'].isin(train['node'])]
df_train = pd.merge(df_train, train, on='node')

df_test = df[df['node'].isin(test['node'])]
df_test = pd.merge(df_test, test, on='node')

total_sec = 0
val_scores = []
test_scores = []

print(f'{"fold":<6} | {"val score":<12} | {"test score":<12} | {"elapsed (sec)":<10}')

for fold in sorted(df[kfold_column].unique()):
    start = datetime.now()
    xtrain =  df_train[df_train.kfold != fold].reset_index(drop=True)
    xvalid = df_train[df_train.kfold == fold].reset_index(drop=True)

    ytrain = xtrain[target_column]
    yvalid = xvalid[target_column]
    
    xtrain = xtrain[emb_columns]
    xvalid = xvalid[emb_columns]

    model = DecisionTreeRegressor(random_state=1)
    model.fit(xtrain, ytrain)

    preds_valid = model.predict(xvalid)
    mse_valid = mean_squared_error(yvalid, preds_valid)

    mse_tst = mean_squared_error(df_test[target_column], model.predict(df_test[emb_columns]))

    sec_elapsed = (datetime.now() - start).total_seconds()
    total_sec += sec_elapsed
    print('{:<6} | {:<12} | {:<12} | {:<10}'.format(fold, format(mse_valid, '.5f'), format(mse_tst, '.5f'), format(sec_elapsed, '.5f')))
    val_scores.append(mse_valid)
    test_scores.append(mse_tst)

val_mean_metric: float = np.mean(val_scores)
val_std: float = np.std(val_scores)

test_mean_metric: float = np.mean(test_scores)
test_std: float = np.std(test_scores)

total_training_time: float = total_sec / 60

print('-' * 30)
print(f'Mean val score: {val_mean_metric:5f}')
print(f'Std val: {val_std:5f}')
print(f'Mean test score: {test_mean_metric:5f}')
print(f'Std test: {test_std:5f}')
print(f'Total elapsed (min): {total_training_time:5f}')
# Out:
# fold   | val score    | test score   | elapsed (sec)
# 0      | 1.04350      | 1.59020      | 11.57365
# 1      | 1.04441      | 1.38573      | 12.69134
# 2      | 0.97755      | 1.34441      | 12.40381
# 3      | 1.02528      | 1.38428      | 14.31029
# 4      | 0.71688      | 1.56583      | 11.52680
# ------------------------------
# Mean val score: 0.961524
# Std val: 0.124709
# Mean test score: 1.454089
# Std test: 0.102553
# Total elapsed (min): 1.041765

# %% [markdown]
# #### Модель `DecisionTreeRegressor` с embedding-ами + дополнительной фичёй "количество связей" и параметрами по умолчанию

# %%
df_train = df[df['node'].isin(train['node'])]
df_train = pd.merge(df, train, on='node')

df_test = df[df['node'].isin(test['node'])]
df_test = pd.merge(df, test, on='node')

total_sec = 0
val_scores = []
test_scores = []

print(f'{"fold":<6} | {"val score":<12} | {"test score":<12} | {"elapsed (sec)":<10}')

for fold in sorted(df[kfold_column].unique()):
    start = datetime.now()
    xtrain =  df_train[df_train.kfold != fold].reset_index(drop=True)
    xvalid = df_train[df_train.kfold == fold].reset_index(drop=True)

    ytrain = xtrain[target_column]
    yvalid = xvalid[target_column]
    
    xtrain = xtrain[emb_columns + count_column]
    xvalid = xvalid[emb_columns + count_column]

    model = DecisionTreeRegressor(random_state=1)
    model.fit(xtrain, ytrain)

    preds_valid = model.predict(xvalid)
    mse_valid = mean_squared_error(yvalid, preds_valid)

    mse_tst = mean_squared_error(df_test[target_column], model.predict(df_test[emb_columns + count_column]))

    sec_elapsed = (datetime.now() - start).total_seconds()
    total_sec += sec_elapsed
    print('{:<6} | {:<12} | {:<12} | {:<10}'.format(fold, format(mse_valid, '.5f'), format(mse_tst, '.5f'), format(sec_elapsed, '.5f')))
    val_scores.append(mse_valid)
    test_scores.append(mse_tst)

val_mean_metric: float = np.mean(val_scores)
val_std: float = np.std(val_scores)

test_mean_metric: float = np.mean(test_scores)
test_std: float = np.std(test_scores)

total_training_time: float = total_sec / 60

print('-' * 30)
print(f'Mean val score: {val_mean_metric:5f}')
print(f'Std val: {val_std:5f}')
print(f'Mean test score: {test_mean_metric:5f}')
print(f'Std test: {test_std:5f}')
print(f'Total elapsed (min): {total_training_time:5f}')
# Out:
# fold   | val score    | test score   | elapsed (sec)
# 0      | 0.26012      | 0.63882      | 7.86585
# 1      | 0.38395      | 0.48325      | 8.10773
# 2      | 0.41519      | 0.50760      | 8.21514
# 3      | 0.33332      | 0.44087      | 7.41453
# 4      | 0.29717      | 0.52012      | 9.01373
# ------------------------------
# Mean val score: 0.337951
# Std val: 0.056259
# Mean test score: 0.518130
# Std test: 0.066133
# Total elapsed (min): 0.676950

# %%
df_train.to_csv('./train_emb.csv', index=None)
df_test.to_csv('./test_emb.csv', index=None)

# %%
regressors = [GradientBoostingRegressor, CatBoostRegressor, LGBMRegressor, XGBRegressor]

models = {}
for reg in tqdm(regressors):
    model = reg(random_state=1)
    model.fit(df_train.drop(['target', 'node'], axis='columns'), df_train['target'])
    mse = mean_squared_error(model.predict(df_test.drop(['target', 'node'], axis='columns')), df_test['target'])
    models[type(model).__name__] = mse

for name, mse in models.items():
    print(f'{name} = {mse:.5f}')
# Out:
#  25%|██▌       | 1/4 [01:04<03:13, 64.38s/it]
# Learning rate set to 0.056868
# 0:	learn: 0.6539479	total: 84.3ms	remaining: 1m 24s
# 1:	learn: 0.6369086	total: 116ms	remaining: 57.8s
# 2:	learn: 0.6215903	total: 142ms	remaining: 47.3s
# 3:	learn: 0.6053108	total: 168ms	remaining: 41.9s
# 4:	learn: 0.5896859	total: 194ms	remaining: 38.6s
# 5:	learn: 0.5749495	total: 226ms	remaining: 37.5s
# 6:	learn: 0.5619029	total: 262ms	remaining: 37.2s
# 7:	learn: 0.5498287	total: 291ms	remaining: 36.1s
# 8:	learn: 0.5381778	total: 319ms	remaining: 35.1s
# 9:	learn: 0.5270785	total: 346ms	remaining: 34.2s
# 10:	learn: 0.5166052	total: 373ms	remaining: 33.6s
# 11:	learn: 0.5071540	total: 400ms	remaining: 32.9s
# 12:	learn: 0.4972954	total: 428ms	remaining: 32.5s
# 13:	learn: 0.4902496	total: 459ms	remaining: 32.4s
# 14:	learn: 0.4825290	total: 495ms	remaining: 32.5s
# 15:	learn: 0.4754537	total: 526ms	remaining: 32.4s
# 16:	learn: 0.4677756	total: 555ms	remaining: 32.1s
# 17:	learn: 0.4613365	total: 581ms	remaining: 31.7s
# 635:	learn: 0.2128517	total: 20.3s	remaining: 11.6s
# 636:	learn: 0.2126878	total: 20.3s	remaining: 11.6s
# 637:	learn: 0.2125813	total: 20.3s	remaining: 11.5s
# 638:	learn: 0.2123223	total: 20.4s	remaining: 11.5s
# 639:	learn: 0.2121637	total: 20.4s	remaining: 11.5s
# 640:	learn: 0.2118349	total: 20.4s	remaining: 11.4s
# 641:	learn: 0.2115580	total: 20.5s	remaining: 11.4s
# 642:	learn: 0.2114251	total: 20.5s	remaining: 11.4s
# 643:	learn: 0.2112740	total: 20.5s	remaining: 11.3s
# 644:	learn: 0.2111599	total: 20.6s	remaining: 11.3s
# 645:	learn: 0.2109550	total: 20.6s	remaining: 11.3s
# 646:	learn: 0.2108135	total: 20.6s	remaining: 11.2s
# 647:	learn: 0.2106614	total: 20.6s	remaining: 11.2s
# 648:	learn: 0.2105577	total: 20.7s	remaining: 11.2s
# 649:	learn: 0.2103991	total: 20.7s	remaining: 11.2s
# 650:	learn: 0.2102519	total: 20.8s	remaining: 11.1s
# 651:	learn: 0.2100514	total: 20.8s	remaining: 11.1s
# 652:	learn: 0.2099146	total: 20.8s	remaining: 11.1s
# 653:	learn: 0.2097339	total: 20.9s	remaining: 11s
# 654:	learn: 0.2096008	total: 20.9s	remaining: 11s
# 655:	learn: 0.2095170	total: 20.9s	remaining: 11s
# 656:	learn: 0.2094037	total: 21s	remaining: 10.9s
# 657:	learn: 0.2092077	total: 21s	remaining: 10.9s
# 658:	learn: 0.2090546	total: 21s	remaining: 10.9s
# 659:	learn: 0.2089150	total: 21s	remaining: 10.8s
# 660:	learn: 0.2087589	total: 21.1s	remaining: 10.8s
# 661:	learn: 0.2086490	total: 21.1s	remaining: 10.8s
# 662:	learn: 0.2084659	total: 21.2s	remaining: 10.8s
# 663:	learn: 0.2083539	total: 21.2s	remaining: 10.7s
# 664:	learn: 0.2082189	total: 21.2s	remaining: 10.7s
# 665:	learn: 0.2080724	total: 21.2s	remaining: 10.7s
# 666:	learn: 0.2079335	total: 21.3s	remaining: 10.6s
# 667:	learn: 0.2077308	total: 21.3s	remaining: 10.6s
# 668:	learn: 0.2075427	total: 21.3s	remaining: 10.6s
# 669:	learn: 0.2074500	total: 21.4s	remaining: 10.5s
# 670:	learn: 0.2073621	total: 21.4s	remaining: 10.5s
# 671:	learn: 0.2072461	total: 21.4s	remaining: 10.5s
# 672:	learn: 0.2071148	total: 21.4s	remaining: 10.4s
# 673:	learn: 0.2070004	total: 21.5s	remaining: 10.4s
# 674:	learn: 0.2068595	total: 21.5s	remaining: 10.4s
# 675:	learn: 0.2067551	total: 21.5s	remaining: 10.3s
# 676:	learn: 0.2065258	total: 21.6s	remaining: 10.3s
# 677:	learn: 0.2064409	total: 21.6s	remaining: 10.3s
# 678:	learn: 0.2062479	total: 21.6s	remaining: 10.2s
# 679:	learn: 0.2061109	total: 21.7s	remaining: 10.2s
# 680:	learn: 0.2060025	total: 21.7s	remaining: 10.2s
# 681:	learn: 0.2058016	total: 21.7s	remaining: 10.1s
# 682:	learn: 0.2056539	total: 21.7s	remaining: 10.1s
# 967:	learn: 0.1675194	total: 30.8s	remaining: 1.02s
# 968:	learn: 0.1674110	total: 30.9s	remaining: 988ms
# 969:	learn: 0.1672981	total: 30.9s	remaining: 956ms
# 970:	learn: 0.1671171	total: 30.9s	remaining: 924ms
# 971:	learn: 0.1669833	total: 31s	remaining: 892ms
# 972:	learn: 0.1669112	total: 31s	remaining: 860ms
# 973:	learn: 0.1667747	total: 31s	remaining: 828ms
# 974:	learn: 0.1666688	total: 31.1s	remaining: 796ms
# 975:	learn: 0.1665471	total: 31.1s	remaining: 764ms
# 976:	learn: 0.1664864	total: 31.1s	remaining: 732ms
# 977:	learn: 0.1664246	total: 31.1s	remaining: 700ms
# 978:	learn: 0.1663579	total: 31.2s	remaining: 668ms
# 979:	learn: 0.1662149	total: 31.2s	remaining: 637ms
# 980:	learn: 0.1661023	total: 31.2s	remaining: 605ms
# 981:	learn: 0.1660042	total: 31.3s	remaining: 573ms
# 982:	learn: 0.1659140	total: 31.3s	remaining: 541ms
# 983:	learn: 0.1657693	total: 31.3s	remaining: 509ms
# 984:	learn: 0.1655637	total: 31.3s	remaining: 477ms
# 985:	learn: 0.1654740	total: 31.4s	remaining: 445ms
# 986:	learn: 0.1653452	total: 31.4s	remaining: 414ms
# 987:	learn: 0.1652038	total: 31.4s	remaining: 382ms
# 988:	learn: 0.1650353	total: 31.5s	remaining: 350ms
# 989:	learn: 0.1649560	total: 31.5s	remaining: 318ms
# 990:	learn: 0.1648916	total: 31.5s	remaining: 286ms
# 991:	learn: 0.1647579	total: 31.6s	remaining: 254ms
# 992:	learn: 0.1645618	total: 31.6s	remaining: 223ms
# 993:	learn: 0.1644160	total: 31.6s	remaining: 191ms
# 994:	learn: 0.1642856	total: 31.6s	remaining: 159ms
# 995:	learn: 0.1641671	total: 31.7s	remaining: 127ms
# 996:	learn: 0.1640924	total: 31.7s	remaining: 95.4ms
# 997:	learn: 0.1640057	total: 31.7s	remaining: 63.6ms
# 998:	learn: 0.1638959	total: 31.8s	remaining: 31.8ms
# 999:	learn: 0.1637657	total: 31.8s	remaining: 0us
# 100%|██████████| 4/4 [01:50<00:00, 27.51s/it]
# GradientBoostingRegressor = 0.30095
# CatBoostRegressor = 0.30737
# LGBMRegressor = 0.31346
# XGBRegressor = 0.32156

# %%
def objective(trial):
    df_train = df[df['node'].isin(train['node'])]
    df_train = pd.merge(df, train, on='node')

    X = df_train[df_train[kfold_column] != 1][emb_columns + count_column]
    y = df_train[df_train[kfold_column] != 1][target_column]
    
    train_x, valid_x, train_y, valid_y = train_test_split(X, y, test_size=0.3)

    param = {
        'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.01, 0.1),
        'depth': trial.suggest_int('depth', 1, 12),
        'boosting_type': trial.suggest_categorical('boosting_type', ['Ordered', 'Plain']),
        'bootstrap_type': trial.suggest_categorical(
            'bootstrap_type', ['Bayesian', 'Bernoulli', 'MVS']
        ),
        'random_state': 1
    }

    if param['bootstrap_type'] == 'Bayesian':
        param['bagging_temperature'] = trial.suggest_float('bagging_temperature', 0, 10)
    elif param['bootstrap_type'] == 'Bernoulli':
        param['subsample'] = trial.suggest_float('subsample', 0.1, 1)

    gbm = CatBoostRegressor(**param)

    gbm.fit(train_x, train_y, eval_set=[(valid_x, valid_y)], verbose=0, early_stopping_rounds=100)

    pred_y = gbm.predict(valid_x)
    score = mean_squared_error(valid_y, pred_y)
    return score

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50, timeout=60*60)
# Out:
# [I 2022-04-17 00:40:34,109] A new study created in memory with name: no-name-00fa01c0-5816-4903-957c-25e01b0da14d
# [I 2022-04-17 00:40:40,091] Trial 0 finished with value: 0.14499392758651286 and parameters: {'colsample_bylevel': 0.043452950266044926, 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 2.9836409720579784}. Best is trial 0 with value: 0.14499392758651286.
# [I 2022-04-17 00:40:41,999] Trial 1 finished with value: 0.18257259064184814 and parameters: {'colsample_bylevel': 0.08803063806912659, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.6475143720691334}. Best is trial 0 with value: 0.14499392758651286.
# [I 2022-04-17 00:40:43,939] Trial 2 finished with value: 0.1382242928476628 and parameters: {'colsample_bylevel': 0.05755573460492932, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.8267094768160684}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:40:46,495] Trial 3 finished with value: 0.1624432990690688 and parameters: {'colsample_bylevel': 0.07720548408998153, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:44:54,343] Trial 4 finished with value: 0.24936604441946192 and parameters: {'colsample_bylevel': 0.032195017933755184, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 8.377577448834561}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:45:17,432] Trial 5 finished with value: 0.31734471984495577 and parameters: {'colsample_bylevel': 0.04767713267051054, 'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:45:21,179] Trial 6 finished with value: 0.17109408098494913 and parameters: {'colsample_bylevel': 0.09723193514350487, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.606179715570946}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:45:22,176] Trial 7 finished with value: 0.1814830552597108 and parameters: {'colsample_bylevel': 0.028191131637791397, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.400066085592922}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:45:38,069] Trial 8 finished with value: 0.3532498898833049 and parameters: {'colsample_bylevel': 0.02471195451109251, 'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 8.038602909799508}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:45:43,950] Trial 9 finished with value: 0.20463554467085077 and parameters: {'colsample_bylevel': 0.0297867617625083, 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.4201425407368786}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:49:27,981] Trial 10 finished with value: 0.21012956582981446 and parameters: {'colsample_bylevel': 0.06860653093785257, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.8201879993257969}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:49:42,999] Trial 11 finished with value: 0.25227251604428 and parameters: {'colsample_bylevel': 0.05106425991912306, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.9986943168099969}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:49:46,150] Trial 12 finished with value: 0.1488304438886164 and parameters: {'colsample_bylevel': 0.0633740632853059, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.20714381364626844}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:49:49,172] Trial 13 finished with value: 0.13851923686431838 and parameters: {'colsample_bylevel': 0.042403579214222276, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.5751332916919747}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:49:51,267] Trial 14 finished with value: 0.19848828309873007 and parameters: {'colsample_bylevel': 0.014953868797479002, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.5981937070593117}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:49:52,418] Trial 15 finished with value: 0.21894588152016806 and parameters: {'colsample_bylevel': 0.05582813759455594, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.5158096949871107}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:49:55,398] Trial 16 finished with value: 0.162370865733876 and parameters: {'colsample_bylevel': 0.03960807860210487, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.6202537103154795}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:49:57,350] Trial 17 finished with value: 0.19577757833507967 and parameters: {'colsample_bylevel': 0.06199492393192792, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.7849645927385851}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:50:13,746] Trial 18 finished with value: 0.18425685314253976 and parameters: {'colsample_bylevel': 0.07936443356617941, 'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.39921131760861667}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:50:15,095] Trial 19 finished with value: 0.20421771809053577 and parameters: {'colsample_bylevel': 0.010731415219583144, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:50:18,104] Trial 20 finished with value: 0.15917643325091174 and parameters: {'colsample_bylevel': 0.07155724432035207, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.8572817446970076}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:50:34,890] Trial 21 finished with value: 0.19252124716046456 and parameters: {'colsample_bylevel': 0.04510706266716024, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.36022082636190417}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:50:51,158] Trial 22 finished with value: 0.19902261500186474 and parameters: {'colsample_bylevel': 0.03886402101962634, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.5342030600903853}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:50:55,453] Trial 23 finished with value: 0.17857045757075574 and parameters: {'colsample_bylevel': 0.0583675634187811, 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:51:03,627] Trial 24 finished with value: 0.2535608885697075 and parameters: {'colsample_bylevel': 0.04102746792294196, 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.6999200002468629}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:53:06,309] Trial 25 finished with value: 0.22788643502170594 and parameters: {'colsample_bylevel': 0.05386884551341382, 'depth': 12, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.0196636578534495}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:53:11,916] Trial 26 finished with value: 0.19714666024838234 and parameters: {'colsample_bylevel': 0.02290984621076957, 'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.9873279440098844}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:53:16,724] Trial 27 finished with value: 0.20390178201423345 and parameters: {'colsample_bylevel': 0.038029526072115065, 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 2.562345279139769}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:53:31,440] Trial 28 finished with value: 0.3330971404277855 and parameters: {'colsample_bylevel': 0.04717834722641614, 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.42811627180224077}. Best is trial 2 with value: 0.1382242928476628.
# [I 2022-04-17 00:53:32,765] Trial 29 finished with value: 0.13550907815986293 and parameters: {'colsample_bylevel': 0.08716969126704911, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 29 with value: 0.13550907815986293.
# [I 2022-04-17 00:53:34,212] Trial 30 finished with value: 0.2077559322376963 and parameters: {'colsample_bylevel': 0.09552161929089369, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 29 with value: 0.13550907815986293.
# [I 2022-04-17 00:53:36,586] Trial 31 finished with value: 0.23965890590055372 and parameters: {'colsample_bylevel': 0.08799911929030133, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 29 with value: 0.13550907815986293.
# [I 2022-04-17 00:53:38,551] Trial 32 finished with value: 0.23551529206426192 and parameters: {'colsample_bylevel': 0.08271035508090695, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 29 with value: 0.13550907815986293.
# [I 2022-04-17 00:53:40,696] Trial 33 finished with value: 0.11247919127810914 and parameters: {'colsample_bylevel': 0.0728563451458045, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.11247919127810914.
# [I 2022-04-17 00:53:44,481] Trial 34 finished with value: 0.23645858267865874 and parameters: {'colsample_bylevel': 0.07195866285022687, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.11247919127810914.
# [I 2022-04-17 00:53:47,032] Trial 35 finished with value: 0.19199698203960555 and parameters: {'colsample_bylevel': 0.0885136920054787, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.11247919127810914.
# [I 2022-04-17 00:53:56,229] Trial 36 finished with value: 0.18896827722084242 and parameters: {'colsample_bylevel': 0.0649456128657069, 'depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.11247919127810914.
# [I 2022-04-17 00:53:58,356] Trial 37 finished with value: 0.19534474148869 and parameters: {'colsample_bylevel': 0.08319684562561455, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.11247919127810914.
# [I 2022-04-17 00:54:01,004] Trial 38 finished with value: 0.14485109839211485 and parameters: {'colsample_bylevel': 0.07555722812586735, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.11247919127810914.
# [I 2022-04-17 00:54:03,837] Trial 39 finished with value: 0.2059803087976207 and parameters: {'colsample_bylevel': 0.08985616846755656, 'depth': 1, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.11247919127810914.
# [I 2022-04-17 00:54:08,082] Trial 40 finished with value: 0.25605512996863605 and parameters: {'colsample_bylevel': 0.06723657305303074, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.11247919127810914.
# [I 2022-04-17 00:54:10,240] Trial 41 finished with value: 0.16432042351860407 and parameters: {'colsample_bylevel': 0.07790405701331606, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.11247919127810914.
# [I 2022-04-17 00:54:12,109] Trial 42 finished with value: 0.18904239061139225 and parameters: {'colsample_bylevel': 0.071190457586919, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.11247919127810914.
# [I 2022-04-17 00:54:14,165] Trial 43 finished with value: 0.16953259516656558 and parameters: {'colsample_bylevel': 0.05891526496020113, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.11247919127810914.
# [I 2022-04-17 00:54:16,421] Trial 44 finished with value: 0.17573271595953338 and parameters: {'colsample_bylevel': 0.07447773200160607, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.11247919127810914.
# [I 2022-04-17 00:54:21,796] Trial 45 finished with value: 0.18037221502979917 and parameters: {'colsample_bylevel': 0.03451620119977544, 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.11247919127810914.
# [I 2022-04-17 00:54:31,967] Trial 46 finished with value: 0.22511286085703208 and parameters: {'colsample_bylevel': 0.09339539558817879, 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.12814375224323804}. Best is trial 33 with value: 0.11247919127810914.
# [I 2022-04-17 00:54:39,516] Trial 47 finished with value: 0.2083703370630684 and parameters: {'colsample_bylevel': 0.050327774485719984, 'depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.7154847636286302}. Best is trial 33 with value: 0.11247919127810914.
# [I 2022-04-17 00:54:43,253] Trial 48 finished with value: 0.19170462695650378 and parameters: {'colsample_bylevel': 0.08377193910263064, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 33 with value: 0.11247919127810914.
# [I 2022-04-17 00:54:44,994] Trial 49 finished with value: 0.19121550732791595 and parameters: {'colsample_bylevel': 0.07890929811225296, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.8974515608013686}. Best is trial 33 with value: 0.11247919127810914.

# %%
print(f'Number of finished trials: {len(study.trials)}')

print('Best trial:')
trial = study.best_trial

print(f'\tValue: {trial.value}')

print('\tParams: ')
for key, value in trial.params.items():
    print(f'\t\t{key}: {value}')
# Out:
# Number of finished trials: 50
# Best trial:
# 	Value: 0.11247919127810914
# 	Params:
# 		colsample_bylevel: 0.0728563451458045
# 		depth: 4
# 		boosting_type: Plain
# 		bootstrap_type: MVS

# %%
df_train = df[df['node'].isin(train['node'])]
df_train = pd.merge(df, train, on='node')

df_test = df[df['node'].isin(test['node'])]
df_test = pd.merge(df, test, on='node')

total_sec = 0
val_scores = []
test_scores = []

print(f'{"fold":<6} | {"val score":<12} | {"test score":<12} | {"elapsed (sec)":<10}')

for fold in sorted(df[kfold_column].unique()):
    start = datetime.now()
    xtrain =  df_train[df_train.kfold != fold].reset_index(drop=True)
    xvalid = df_train[df_train.kfold == fold].reset_index(drop=True)

    ytrain = xtrain[target_column]
    yvalid = xvalid[target_column]
    
    xtrain = xtrain[emb_columns + count_column]
    xvalid = xvalid[emb_columns + count_column]

    model = CatBoostRegressor(random_state=1, **trial.params)
    model.fit(xtrain, ytrain, silent=True)

    preds_valid = model.predict(xvalid)
    mse_valid = mean_squared_error(yvalid, preds_valid)

    mse_tst = mean_squared_error(df_test[target_column], model.predict(df_test[emb_columns + count_column]))

    sec_elapsed = (datetime.now() - start).total_seconds()
    total_sec += sec_elapsed
    print('{:<6} | {:<12} | {:<12} | {:<10}'.format(fold, format(mse_valid, '.5f'), format(mse_tst, '.5f'), format(sec_elapsed, '.5f')))
    val_scores.append(mse_valid)
    test_scores.append(mse_tst)

val_mean_metric: float = np.mean(val_scores)
val_std: float = np.std(val_scores)

test_mean_metric: float = np.mean(test_scores)
test_std: float = np.std(test_scores)

total_training_time: float = total_sec / 60

print('-' * 30)
print(f'Mean val score: {val_mean_metric:5f}')
print(f'Std val: {val_std:5f}')
print(f'Mean test score: {test_mean_metric:5f}')
print(f'Std test: {test_std:5f}')
print(f'Total elapsed (min): {total_training_time:5f}')
# Out:
# fold   | val score    | test score   | elapsed (sec)
# 0      | 0.12796      | 0.30242      | 4.05563
# 1      | 0.16170      | 0.30128      | 3.81658
# 2      | 0.22124      | 0.30690      | 3.80824
# 3      | 0.20481      | 0.30228      | 3.86723
# 4      | 0.16134      | 0.30292      | 3.77861
# ------------------------------
# Mean val score: 0.175410
# Std val: 0.033473
# Mean test score: 0.303162
# Std test: 0.001945
# Total elapsed (min): 0.322105

# %% [markdown]
# Итоговая модель получилась в два раза лучше baseline модели
